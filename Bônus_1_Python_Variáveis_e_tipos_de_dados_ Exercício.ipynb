# %% [markdown]
# Exercício 1

# %%
saudação = "Olá mundo"

print(saudação)
# Out:
# 'Olá mundo'

# %% [markdown]
# ![6041d3043d8e9c6f79a68c85_humanity-technology-handshake-ss-1920_dtp9xy.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Exercicio 2

# %%
QTV_19 = 3
TM_19 = 320.52
VTV_19 = TM_19/QTV_19
print(VTV_19)
# Out:
# '106.83999999999999'

# %%
VTV_20 = 834.47
TM_20 = 119.21
QTV_20 = VTV_20 / TM_20
print(QTV_20)
# Out:
# '7.000000000000001'

# %%
VTV_23 = 15378.12
QTV_23 = 5
TM_23 = VTV_23 / QTV_23
print(TM_23)
# Out:
# '3075.6240000000003'

# %%
cancao = "Roda mundo, roda gigante; roda moinho, roda pião."
posição_virgula = cancao.find(";")
print(posição_virgula)
# Out:
# 24

# %% [markdown]
# Exercico 3

# %%
cancao = "Roda mundo, roda gigante; roda moinho, roda pião."
segunda_parte = cancao[25:len(cancao)]
print(segunda_parte)
# Out:
#  roda moinho, roda pião.

# %%
cancao = "Roda mundo, roda gigante; roda moinho, roda pião."
miolo = cancao[11:37]
print(miolo)
# Out:
#  roda gigante; roda moinho

# %%
noticia = "Selic vai a 2,75% e supera expectativas; + \ é a primeira alta em 6 anos."
Selic = noticia[12:17]
print(Selic)
print(type(Selic))
numerico = Selic[0:4]
print(numerico)
ano = noticia[66:72]
print(ano)
# Out:
# 2,75%
# <class 'str'>
# 2,75
# 6 anos

# %% [markdown]
# Exercicio 4

# %%
a = False
b = True
print(not(a))
print(not(b))
x = not(a) & b
print(x)
# Out:
# True
# False
# True
